# %% [markdown]
# # ADVANCED TEXT MINING
# - 본 자료는 텍스트 마이닝을 활용한 연구 및 강의를 위한 목적으로 제작되었습니다.
# - 본 자료를 강의 목적으로 활용하고자 하시는 경우 꼭 아래 메일주소로 연락주세요.
# - 본 자료에 대한 허가되지 않은 배포를 금지합니다.
# - 강의, 저작권, 출판, 특허, 공동저자에 관련해서는 문의 바랍니다.
# - **Contact : ADMIN(admin@teanaps.com)**
#
# ---

# %%
# 텍스트 분석을 위한 TEANAPS 패키지를 설치합니다.
# TEANAPS는 Google Colaboratory/Linux 환경에 최적화되어 있습니다.
# Windows 환경에서 일부 기능에 제한이 있을 수 있습니다.

# %%
# TEANAPS (https://github.com/fingeredman/teanaps)
#!git clone https://github.com/fingeredman/teanaps.git

# %%
#!ls

# %%
#!python "teanaps/teanaps_setup.py"

# %% [markdown]
# ## WEEK 11-1. 개봉전 영화리뷰로 총 관객수 예측하기
# - Python으로 개봉전 영화리뷰를 활용해 총 관객수를 예측하는 방법에 대해 다룹니다.
#
# ---

# %% [markdown]
# ### 1. 학습데이터 준비하기
#
# ---

# %% [markdown]
# #### 1.1. TEANAPS 라이브러리 불러오기
#
# ---

# %%
from teanaps.nlp import MorphologicalAnalyzer
from teanaps.nlp import Processing
from teanaps.handler import FileHandler
from teanaps.text_analysis import TfidfCalculator

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import matplotlib.pyplot as plt

ma = MorphologicalAnalyzer()
ma.set_tagger("mecab")
tfidf = TfidfCalculator()
processing = Processing()
fh = FileHandler()

# %% [markdown]
# #### 1.2. 데이터 파일 불러오기: 영화정보
#
# ---

# %%
movie_dict = {}

f = open("data/movie_list.txt", encoding="utf-8")
for line in f:
    line = line.strip()
    col = line.split("\t")
    movie_name = col[0]
    opening_date = col[1]
    viewer = int(col[2].strip().replace(",", ""))
    movie_code = col[3]
    movie_dict[movie_name] = {"viewer": viewer, "opening_date": opening_date}
f.close()

# %%
movie_dict
# Out:
# {'택시운전사': {'viewer': 12186327, 'opening_date': '20170802'},
#  '공조': {'viewer': 7817618, 'opening_date': '20170118'},
#  '스파이더맨: 홈 커밍': {'viewer': 7258678, 'opening_date': '20170705'},
#  '범죄도시': {'viewer': 6879841, 'opening_date': '20171003'},
#  '군함도': {'viewer': 6592151, 'opening_date': '20170726'},
#  '청년경찰': {'viewer': 5653270, 'opening_date': '20170809'},
#  '더 킹': {'viewer': 5317693, 'opening_date': '20170118'},
#  '미녀와 야수': {'viewer': 5138328, 'opening_date': '20170316'},
#  '킹스맨: 골든 서클': {'viewer': 4945484, 'opening_date': '20170927'},
#  '토르: 라그나로크': {'viewer': 4853778, 'opening_date': '20171025'},
#  '꾼': {'viewer': 4018035, 'opening_date': '20171122'},
#  '남한산성': {'viewer': 3849087, 'opening_date': '20171003'},
#  '미이라': {'viewer': 3689325, 'opening_date': '20170606'},
#  '분노의 질주: 더 익스트림': {'viewer': 3653238, 'opening_date': '20170412'},
#  '너의 이름은.': {'viewer': 3637608, 'opening_date': '20170104'},
#  '슈퍼배드 3': {'viewer': 3324874, 'opening_date': '20170726'},
#  '아이 캔 스피크': {'viewer': 3279296, 'opening_date': '20170921'},
#  '캐리비안의 해적: 죽은 자는 말이 없다': {'viewer': 3049894, 'opening_date': '20170524'},
#  '프리즌': {'viewer': 2931897, 'opening_date': '20170323'},
#  '덩케르크': {'viewer': 2788732, 'opening_date': '20170720'},
#  '가디언즈 오브 갤럭시 VOL. 2': {'viewer': 2735721, 'opening_date': '20170503'},
#  '살인자의 기억법': {'viewer': 2658589, 'opening_date': '20170906'},
#  '트랜스포머: 최후의 기사': {'viewer': 2614601, 'opening_date': '20170621'},
#  '보안관': {'viewer': 2588628, 'opening_date': '20170503'},
#  '조작된 도시': {'viewer': 2515501, 'opening_date': '20170209'},
#  '보스 베이비': {'viewer': 2452245, 'opening_date': '20170503'},
#  '재심': {'viewer': 2421197, 'opening_date': '20170215'},
#  '박열': {'viewer': 2359206, 'opening_date': '20170628'},
#  '모아나': {'viewer': 2310206, 'opening_date': '20170112'},
#  '마스터': {'viewer': 2215266, 'opening_date': '20161221'},
#  '로건': {'viewer': 2169109, 'opening_date': '20170301'},
#  '원더 우먼': {'viewer': 2165401, 'opening_date': '20170531'},
#  '겟 아웃': {'viewer': 2138174, 'opening_date': '20170517'},
#  '혹성탈출: 종의 전쟁': {'viewer': 2051315, 'opening_date': '20170815'},
#  '애나벨 : 인형의 주인': {'viewer': 1934270, 'opening_date': '20170810'},
#  '노무현입니다': {'viewer': 1855149, 'opening_date': '20170525'},
#  '저스티스 리그': {'viewer': 1786383, 'opening_date': '20171115'},
#  '킬러의 보디가드': {'viewer': 1721757, 'opening_date': '20170830'},
#  '콩: 스컬 아일랜드': {'viewer': 1689717, 'opening_date': '20170308'},
#  '23 아이덴티티': {'viewer': 1675819, 'opening_date': '20170222'},
#  '임금님의 사건수첩': {'viewer': 1635003, 'opening_date': '20170426'},
#  '부라더': {'viewer': 1492903, 'opening_date': '20171102'},
#  '기억의 밤': {'viewer': 1386611, 'opening_date': '20171129'},
#  '해피 데스데이': {'viewer': 1382650, 'opening_date': '20171108'},
#  '브이아이피': {'viewer': 1373316, 'opening_date': '20170823'},
#  '특별시민': {'viewer': 1362634, 'opening_date': '20170426'},
#  '에이리언: 커버넌트': {'viewer': 1307226, 'opening_date': '20170509'},
#  '장산범': {'viewer': 1306438, 'opening_date': '20170817'},
#  '악녀': {'viewer': 1208081, 'opening_date': '20170608'},
#  '해빙': {'viewer': 1204600, 'opening_date': '20170301'},
#  '라라랜드': {'viewer': 1185287, 'opening_date': '20161207'},
#  '하루': {'viewer': 1129609, 'opening_date': '20170615'},
#  '지오스톰': {'viewer': 1028384, 'opening_date': '20171019'},
#  '스타워즈: 라스트 제다이': {'viewer': 946547, 'opening_date': '20171214'},
#  '불한당: 나쁜 놈들의 세상': {'viewer': 939535, 'opening_date': '20170517'},
#  '그것': {'viewer': 888836, 'opening_date': '20170906'},
#  '오리엔트 특급 살인': {'viewer': 863567, 'opening_date': '20171129'},
#  '대립군': {'viewer': 837500, 'opening_date': '20170531'},
#  '베이비 드라이버': {'viewer': 822769, 'opening_date': '20170914'},
#  '뽀로로 극장판 공룡섬 대모험': {'viewer': 773743, 'opening_date': '20171207'},
#  '레지던트 이블: 파멸의 날': {'viewer': 765259, 'opening_date': '20170125'},
#  '공각기동대 : 고스트 인 더 쉘': {'viewer': 764072, 'opening_date': '20170329'},
#  '트롤': {'viewer': 675966, 'opening_date': '20170216'},
#  '패신저스': {'viewer': 668576, 'opening_date': '20170104'},
#  '씽': {'viewer': 667598, 'opening_date': '20161221'},
#  '아빠는 딸': {'viewer': 647305, 'opening_date': '20170412'},
#  '컨택트': {'viewer': 634150, 'opening_date': '20170202'},
#  '47 미터': {'viewer': 590045, 'opening_date': '20170719'},
#  '메리와 마녀의 꽃': {'viewer': 535331, 'opening_date': '20171207'},
#  '얼라이드': {'viewer': 518886, 'opening_date': '20170111'},
#  '발레리안: 천 개 행성의 도시': {'viewer': 511931, 'opening_date': '20170830'},
#  '그레이트 월': {'viewer': 501486, 'opening_date': '20170215'},
#  '침묵': {'viewer': 494097, 'opening_date': '20171102'},
#  '카3: 새로운 도전': {'viewer': 487916, 'opening_date': '20170713'},
#  '트리플 엑스 리턴즈': {'viewer': 475309, 'opening_date': '20170208'},
#  '리얼': {'viewer': 470105, 'opening_date': '20170628'},
#  '너의 췌장을 먹고 싶어': {'viewer': 465265, 'opening_date': '20171025'},
#  '라이프': {'viewer': 459984, 'opening_date': '20170405'},
#  '명탐정 코난:진홍의 연가': {'viewer': 450043, 'opening_date': '20170802'},
#  '히든 피겨스': {'viewer': 449518, 'opening_date': '20170323'},
#  '반드시 잡는다': {'viewer': 446780, 'opening_date': '20171129'},
#  '원라인': {'viewer': 435048, 'opening_date': '20170329'},
#  '터닝메카드W: 블랙미러의 부활': {'viewer': 429933, 'opening_date': '20170118'},
#  '스머프: 비밀의 숲': {'viewer': 427764, 'opening_date': '20170428'},
#  '로그 원: 스타워즈 스토리': {'viewer': 422822, 'opening_date': '20161228'},
#  '킹 아서: 제왕의 검': {'viewer': 415714, 'opening_date': '20170517'},
#  '극장판 포켓몬스터 너로 정했다!': {'viewer': 415255, 'opening_date': '20171221'},
#  '넛잡 2': {'viewer': 411787, 'opening_date': '20171003'},
#  '아메리칸 메이드': {'viewer': 401541, 'opening_date': '20170914'},
#  '러빙 빈센트': {'viewer': 384540, 'opening_date': '20171109'},
#  '보통사람': {'viewer': 383336, 'opening_date': '20170323'},
#  '대장 김창수': {'viewer': 381483, 'opening_date': '20171019'},
#  '눈의 여왕 3: 눈과 불의 마법대결': {'viewer': 366442, 'opening_date': '20170104'},
#  '어쌔신 크리드': {'viewer': 355913, 'opening_date': '20170111'},
#  '플립': {'viewer': 355617, 'opening_date': '20170712'},
#  '석조저택 살인사건': {'viewer': 353517, 'opening_date': '20170509'},
#  '극한직업': {'viewer': 16265618, 'opening_date': '20190123'},
#  '어벤져스: 엔드게임': {'viewer': 13934592, 'opening_date': '20190424'},
#  '겨울왕국 2': {'viewer': 13369064, 'opening_date': '20191121'},
#  '알라딘': {'viewer': 12552283, 'opening_date': '20190523'},
#  '기생충': {'viewer': 10085275, 'opening_date': '20190530'},
#  '엑시트': {'viewer': 9426011, 'opening_date': '20190731'},
#  '스파이더맨: 파 프롬 홈': {'viewer': 8021145, 'opening_date': '20190702'},
#  '백두산': {'viewer': 6290502, 'opening_date': '20191219'},
#  '캡틴 마블': {'viewer': 5802810, 'opening_date': '20190306'},
#  '조커': {'viewer': 5247874, 'opening_date': '20191002'},
#  '봉오동 전투': {'viewer': 4787538, 'opening_date': '20190807'},
#  '라이온 킹': {'viewer': 4743264, 'opening_date': '20190717'},
#  '나쁜 녀석들: 더 무비': {'viewer': 4573902, 'opening_date': '20190911'},
#  '82년생 김지영': {'viewer': 3678156, 'opening_date': '20191023'},
#  '분노의 질주: 홉스&쇼': {'viewer': 3657536, 'opening_date': '20190814'},
#  '토이 스토리 4': {'viewer': 3400034, 'opening_date': '20190620'},
#  '돈': {'viewer': 3389125, 'opening_date': '20190320'},
#  '악인전': {'viewer': 3364712, 'opening_date': '20190515'},
#  '가장 보통의 연애': {'viewer': 2924563, 'opening_date': '20191002'},
#  '말모이': {'viewer': 2812877, 'opening_date': '20190109'},
#  '증인': {'viewer': 2534748, 'opening_date': '20190213'},
#  '시동': {'viewer': 2525986, 'opening_date': '20191218'},
#  '블랙머니': {'viewer': 2478964, 'opening_date': '20191113'},
#  '터미네이터: 다크 페이트': {'viewer': 2409062, 'opening_date': '20191030'},
#  '사바하': {'viewer': 2398519, 'opening_date': '20190220'},
#  '타짜: 원 아이드 잭': {'viewer': 2229239, 'opening_date': '20190911'},
#  '신의 한 수: 귀수편': {'viewer': 2157437, 'opening_date': '20191107'},
#  '알리타: 배틀 엔젤': {'viewer': 1952063, 'opening_date': '20190205'},
#  '내안의 그놈': {'viewer': 1902828, 'opening_date': '20190109'},
#  '뺑반': {'viewer': 1826912, 'opening_date': '20190130'},
#  '변신': {'viewer': 1804112, 'opening_date': '20190821'},
#  '주먹왕 랄프 2: 인터넷 속으로': {'viewer': 1754375, 'opening_date': '20190103'},
#  '걸캅스': {'viewer': 1629528, 'opening_date': '20190509'},
#  '사자': {'viewer': 1611163, 'opening_date': '20190731'},
#  '드래곤 길들이기 3': {'viewer': 1507922, 'opening_date': '20190130'},
#  '나의 특별한 형제': {'viewer': 1478156, 'opening_date': '20190501'},
#  '어스': {'viewer': 1475087, 'opening_date': '20190327'},
#  '말레피센트 2': {'viewer': 1444952, 'opening_date': '20191017'},
#  '유열의 음악앨범': {'viewer': 1245532, 'opening_date': '20190828'},
#  '퍼펙트맨': {'viewer': 1240022, 'opening_date': '20191002'},
#  '포드 V 페라리': {'viewer': 1208407, 'opening_date': '20191204'},
#  '생일': {'viewer': 1197565, 'opening_date': '20190403'},
#  '힘을 내요, 미스터 리': {'viewer': 1181960, 'opening_date': '20190911'},
#  '항거:유관순 이야기': {'viewer': 1157949, 'opening_date': '20190227'},
#  '장사리 : 잊혀진 영웅들': {'viewer': 1140876, 'opening_date': '20190925'},
#  '마이펫의 이중생활 2': {'viewer': 1114949, 'opening_date': '20190731'},
#  '롱 리브 더 킹: 목포 영웅': {'viewer': 1094404, 'opening_date': '20190619'},
#  '쥬만지: 넥스트 레벨': {'viewer': 1054963, 'opening_date': '20191211'},
#  '존 윅 3: 파라벨룸': {'viewer': 1004365, 'opening_date': '20190626'},
#  '천문: 하늘에 묻는다': {'viewer': 965624, 'opening_date': '20191226'},
#  '나랏말싸미': {'viewer': 958775, 'opening_date': '20190724'},
#  '엑스맨: 다크 피닉스': {'viewer': 862744, 'opening_date': '20190605'},
#  '맨 인 블랙: 인터내셔널': {'viewer': 851917, 'opening_date': '20190612'},
#  '레드슈즈': {'viewer': 817729, 'opening_date': '20190725'},
#  '뽀로로 극장판 보물섬 대모험': {'viewer': 766843, 'opening_date': '20190425'},
#  '캣츠': {'viewer': 728328, 'opening_date': '20191224'},
#  '명탐정 피카츄': {'viewer': 686809, 'opening_date': '20190509'},
#  '신비아파트 극장판 하늘도깨비 대 요르문간드': {'viewer': 672122, 'opening_date': '20191219'},
#  '나이브스 아웃': {'viewer': 667411, 'opening_date': '20191204'},
#  '샤잠!': {'viewer': 657294, 'opening_date': '20190403'},
#  '날씨의 아이': {'viewer': 655876, 'opening_date': '20191030'},
#  '나를 찾아줘': {'viewer': 645082, 'opening_date': '20191127'},
#  '광대들: 풍문조작단': {'viewer': 637461, 'opening_date': '20190821'},
#  '그것: 두 번째 이야기': {'viewer': 591346, 'opening_date': '20190904'},
#  '극장판 헬로카봇 : 달나라를 구해줘!': {'viewer': 590413, 'opening_date': '20190904'},
#  '극장판 헬로카봇: 옴파로스 섬의 비밀': {'viewer': 575362, 'opening_date': '20190131'},
#  '이스케이프 룸': {'viewer': 563114, 'opening_date': '20190314'},
#  '양자물리학': {'viewer': 554939, 'opening_date': '20190925'},
#  '애드 아스트라': {'viewer': 513375, 'opening_date': '20190919'},
#  '47미터 2': {'viewer': 501934, 'opening_date': '20190828'},
#  '애나벨 집으로': {'viewer': 481766, 'opening_date': '20190626'},
#  '감쪽같은 그녀': {'viewer': 469296, 'opening_date': '20191204'},
#  '글래스': {'viewer': 466475, 'opening_date': '20190117'},
#  '그린 북': {'viewer': 434899, 'opening_date': '20190109'},
#  '장난스런 키스': {'viewer': 428009, 'opening_date': '20190327'},
#  '해피 데스데이 2 유': {'viewer': 412850, 'opening_date': '20190214'},
#  '극장판 공룡메카드: 타이니소어의 섬': {'viewer': 410132, 'opening_date': '20190110'},
#  '제미니 맨': {'viewer': 387342, 'opening_date': '20191009'},
#  '고질라: 킹 오브 몬스터': {'viewer': 359041, 'opening_date': '20190529'},
#  '덤보': {'viewer': 345521, 'opening_date': '20190327'},
#  '러브 유어셀프 인 서울': {'viewer': 342366, 'opening_date': '20190126'},
#  '브링 더 소울 : 더 무비': {'viewer': 336074, 'opening_date': '20190807'},
#  '아담스 패밀리': {'viewer': 329955, 'opening_date': '20191107'},
#  '헬보이': {'viewer': 323198, 'opening_date': '20190410'},
#  '예스터데이': {'viewer': 306332, 'opening_date': '20190918'},
#  '천로역정: 천국을 찾아서': {'viewer': 296588, 'opening_date': '20190613'},
#  '미성년': {'viewer': 293352, 'opening_date': '20190411'},
#  '배심원들': {'viewer': 288579, 'opening_date': '20190515'},
#  '기방도령': {'viewer': 287053, 'opening_date': '20190710'},
#  '신데렐라:마법 반지의 비밀': {'viewer': 284922, 'opening_date': '20190220'},
#  '원스 어폰 어 타임... 인 할리우드': {'viewer': 277319, 'opening_date': '20190925'},
#  '기묘한 가족': {'viewer': 263598, 'opening_date': '20190213'},
#  '악질경찰': {'viewer': 262233, 'opening_date': '20190320'},
#  '라스트 크리스마스': {'viewer': 249323, 'opening_date': '20191205'},
#  '메리 포핀스 리턴즈': {'viewer': 224160, 'opening_date': '20190214'},
#  '명탐정 코난: 감청의 권': {'viewer': 219078, 'opening_date': '20190724'},
#  '신과함께-인과 연': {'viewer': 12274996, 'opening_date': '20180801'},
#  '어벤져스: 인피니티 워': {'viewer': 11212710, 'opening_date': '20180425'},
#  '미션 임파서블: 폴아웃': {'viewer': 6584915, 'opening_date': '20180725'},
#  '쥬라기 월드: 폴른 킹덤': {'viewer': 5661128, 'opening_date': '20180606'},
#  '앤트맨과 와스프': {'viewer': 5448134, 'opening_date': '20180704'},
#  '안시성': {'viewer': 5440186, 'opening_date': '20180919'},
#  '블랙 팬서': {'viewer': 5399227, 'opening_date': '20180214'},
#  '완벽한 타인': {'viewer': 5293435, 'opening_date': '20181031'},
#  '독전': {'viewer': 5063684, 'opening_date': '20180522'},
#  '공작': {'viewer': 4974520, 'opening_date': '20180808'},
#  '베놈': {'viewer': 3888096, 'opening_date': '20181003'},
#  '암수살인': {'viewer': 3789321, 'opening_date': '20181003'},
#  '데드풀 2': {'viewer': 3784602, 'opening_date': '20180516'},
#  '국가부도의 날': {'viewer': 3747952, 'opening_date': '20181128'},
#  '코코': {'viewer': 3510017, 'opening_date': '20180111'},
#  '그것만이 내 세상': {'viewer': 3419339, 'opening_date': '20180117'},
#  '마녀': {'viewer': 3189091, 'opening_date': '20180627'},
#  '탐정: 리턴즈': {'viewer': 3152872, 'opening_date': '20180613'},
#  '인크레더블 2': {'viewer': 3033052, 'opening_date': '20180718'},
#  '서치': {'viewer': 2949944, 'opening_date': '20180829'},
#  '너의 결혼식': {'viewer': 2820969, 'opening_date': '20180822'},
#  '곤지암': {'viewer': 2675575, 'opening_date': '20180328'},
#  '지금 만나러 갑니다': {'viewer': 2602273, 'opening_date': '20180314'},
#  '목격자': {'viewer': 2524720, 'opening_date': '20180815'},
#  '조선명탐정: 흡혈괴마의 비밀': {'viewer': 2444136, 'opening_date': '20180208'},
#  '신비한 동물들과 그린델왈드의 범죄': {'viewer': 2414062, 'opening_date': '20181114'},
#  '메이즈 러너: 데스 큐어': {'viewer': 2299732, 'opening_date': '20180117'},
#  '맘마미아!2': {'viewer': 2293884, 'opening_date': '20180808'},
#  '레디 플레이어 원': {'viewer': 2254430, 'opening_date': '20180328'},
#  '명당': {'viewer': 2087474, 'opening_date': '20180919'},
#  '협상': {'viewer': 1967721, 'opening_date': '20180919'},
#  '마약왕': {'viewer': 1813594, 'opening_date': '20181219'},
#  '쥬만지: 새로운 세계': {'viewer': 1708672, 'opening_date': '20180103'},
#  '창궐': {'viewer': 1599290, 'opening_date': '20181025'},
#  '성난황소': {'viewer': 1593386, 'opening_date': '20181122'},
#  '도어락': {'viewer': 1559616, 'opening_date': '20181205'},
#  '리틀 포레스트': {'viewer': 1506269, 'opening_date': '20180228'},
#  '골든슬럼버': {'viewer': 1387508, 'opening_date': '20180214'},
#  '램페이지': {'viewer': 1385511, 'opening_date': '20180412'},
#  '궁합': {'viewer': 1340117, 'opening_date': '20180228'},
#  '오션스8': {'viewer': 1335829, 'opening_date': '20180613'},
#  '사라진 밤': {'viewer': 1315726, 'opening_date': '20180307'},
#  '스윙키즈': {'viewer': 1258811, 'opening_date': '20181219'},
#  '바람 바람 바람': {'viewer': 1194229, 'opening_date': '20180405'},
#  '챔피언': {'viewer': 1128774, 'opening_date': '20180501'},
#  '퍼시픽 림: 업라이징': {'viewer': 1077235, 'opening_date': '20180321'},
#  '몬스터 호텔 3': {'viewer': 1072220, 'opening_date': '20180808'},
#  '더 넌': {'viewer': 1011580, 'opening_date': '20180919'},
#  '스카이스크래퍼': {'viewer': 1002858, 'opening_date': '20180711'},
#  '염력': {'viewer': 990104, 'opening_date': '20180131'},
#  '월요일이 사라졌다': {'viewer': 903175, 'opening_date': '20180222'},
#  '인랑': {'viewer': 898945, 'opening_date': '20180725'},
#  '극장판 헬로카봇 : 백악기 시대': {'viewer': 879449, 'opening_date': '20180801'},
#  '레슬러': {'viewer': 771141, 'opening_date': '20180509'},
#  '상류사회': {'viewer': 768442, 'opening_date': '20180829'},
#  '물괴': {'viewer': 723622, 'opening_date': '20180912'},
#  '미쓰백': {'viewer': 722182, 'opening_date': '20181011'},
#  '신비아파트: 금빛 도깨비와 비밀의 동굴': {'viewer': 678091, 'opening_date': '20180725'},
#  '퍼스트맨': {'viewer': 665364, 'opening_date': '20181018'},
#  '스파이더맨: 뉴 유니버스': {'viewer': 639934, 'opening_date': '20181212'},
#  '인시디어스4: 라스트 키': {'viewer': 554521, 'opening_date': '20180131'},
#  '그날, 바다': {'viewer': 540631, 'opening_date': '20180412'},
#  '툼레이더': {'viewer': 540410, 'opening_date': '20180308'},
#  '페르디난드': {'viewer': 533776, 'opening_date': '20180103'},
#  '버닝': {'viewer': 528435, 'opening_date': '20180517'},
#  '7년의 밤': {'viewer': 528007, 'opening_date': '20180328'},
#  '메가로돈': {'viewer': 527962, 'opening_date': '20180815'},
#  '콰이어트 플레이스': {'viewer': 526073, 'opening_date': '20180412'},
#  '호두까기 인형과 4개의 왕국': {'viewer': 513767, 'opening_date': '20181206'},
#  '셰이프 오브 워터: 사랑의 모양': {'viewer': 507102, 'opening_date': '20180222'},
#  '곰돌이 푸 다시 만나 행복해': {'viewer': 492201, 'opening_date': '20181003'},
#  '변산': {'viewer': 490519, 'opening_date': '20180704'},
#  '그린치': {'viewer': 485064, 'opening_date': '20181219'},
#  '스타 이즈 본': {'viewer': 483852, 'opening_date': '20181009'},
#  '동네사람들': {'viewer': 461693, 'opening_date': '20181107'},
#  '원더풀 고스트': {'viewer': 450374, 'opening_date': '20180926'},
#  '흥부: 글로 세상을 바꾼 자': {'viewer': 416303, 'opening_date': '20180214'},
#  '명탐정 코난 : 제로의 집행인': {'viewer': 396230, 'opening_date': '20180808'},
#  '피터 래빗': {'viewer': 388300, 'opening_date': '20180516'},
#  '점박이 한반도의 공룡2 : 새로운 낙원': {'viewer': 375312, 'opening_date': '20181225'},
#  '패딩턴 2': {'viewer': 339014, 'opening_date': '20180208'},
#  '허스토리': {'viewer': 336822, 'opening_date': '20180627'},
#  '미드나잇 선': {'viewer': 326086, 'opening_date': '20180621'},
#  '덕구': {'viewer': 315663, 'opening_date': '20180405'},
#  '번 더 스테이지: 더 무비': {'viewer': 315010, 'opening_date': '20181115'},
#  '트루스 오어 데어': {'viewer': 310956, 'opening_date': '20180522'},
#  '커뮤터': {'viewer': 286062, 'opening_date': '20180124'},
#  '후드': {'viewer': 284601, 'opening_date': '20181128'},
#  '극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~': {'viewer': 277206,
#   'opening_date': '20181219'},
#  '해리포터와 마법사의 돌': {'viewer': 267950, 'opening_date': '20011213'},
#  '모털 엔진': {'viewer': 267896, 'opening_date': '20181205'},
#  '바울': {'viewer': 267785, 'opening_date': '20181031'}}

# %% [markdown]
# #### 1.3. 데이터 파일 불러오기: 영화리뷰
#
# ---

# %%
import datetime

data = []
progress = 0

f = open("data/movie_comment_17-19_pre.txt", encoding="utf-8")
for line in f:
    progress += 1
    print(progress, end="\r")
    
    line = line.replace("\n", "")
    #print(line)
    col = line.split("\t")
    movie_name = col[0]
    date_time = col[1]
    #_date_time = datetime.datetime.strptime(date_time, "%Y.%m.%d %H:%M")
    opening_date = movie_dict[movie_name]["opening_date"]
    #opening_date = datetime.datetime.strptime(opening_date, "%Y%m%d")
    comment = col[2]
    # 개봉일 이전 리뷰만 필터링
    #print(_date_time, opening_date)
    #if _date_time <= opening_date + datetime.timedelta(days=3):
    data.append([movie_name, date_time, comment])
f.close()
# Out:
# 684270

# %%
print(len(data))
# Out:
# 684270

# %%
data[:3]
# Out:
# [['택시운전사',
#   '2017.08.02 09:29',
#   '송강호 유해진 류준열이 한번씩 눈물 쏟게 만듦.. 그날의 광주에 택시운전사와 함께 다녀온 듯 먹먹하다'],
#  ['택시운전사', '2017.08.02 09:28', '최근에 본 영화중 가장 돈이 안 아까운 영화!'],
#  ['택시운전사',
#   '2017.08.02 09:24',
#   '신파일까봐 걱정했는데 신파는 커녕 눈물이 날만하면 가차없이 유쾌함을 던져주던 담백한 영화,,덕분에 억지 눈물이 아닌 진짜 눈물만 나왔다']]

# %% [markdown]
# #### 1.4. 텍스트 데이터 임베딩: TF-IDF Matrix
#
# ---

# %%
movie_comment_dict = {}
POS_LIST = ["NNP", "NNG"]

index = 0
for movie_name, date_time, comment in data:
    index += 1
    print(index, end="\r")
    
    # 명사형 문장 만들기
    pos_result = ma.parse(comment)
    pos_sentence = processing.get_plain_text(pos_result, pos_list=POS_LIST, tag=False)
    
    # 영화별 명사형 문장 Dictionary에 저장하기
    if movie_name in movie_comment_dict.keys():
        movie_comment_dict[movie_name] += " " + pos_sentence
    else:
        movie_comment_dict[movie_name] = pos_sentence
# Out:
# 684270

# %%
movie_comment_list = []
movie_viewer_list = []

for movie_name, pos_sentence_list in movie_comment_dict.items():
    movie_comment_list.append(pos_sentence_list)
    movie_viewer_list.append(movie_dict[movie_name]["viewer"])

# %%
len(movie_comment_list)
# Out:
# 283

# %%
movie_comment_list[0]
# Out:
# '송강호 유해진 류준열 눈물 그날 광주 택시 운전사 최근 영화 돈 영화 신파 걱정 신파 눈물 날 영화 덕분 억지 눈물 눈물 영화 권력 굴복 시민 위르겐 힌츠페터 감사 배우 연기 역사 상황 가슴 픽션 사실 기반 영화 눈물 옆 자리 할머니 할아버지 눈물 빨갱이 단어 전두환 최대한 목격 광주 울림 영화 시사회 소재 마음 영화 영화 강추 이번 시사회 당첨 신랑 영화 끝 마음 후회 한국 영화 기대 합 당 아침 여운 그날 시선 감동 웃음 드라마 오늘 하루 생각 그때 상황 말 연기 몰입 영화 영화 유쾌 가슴 간만 영화 송강호 유해진 류준열 연기 최고 위르겐 힌츠페터 인물 재미 슬픔 감동 영화 가족 부모 강추 땅 감사 송강호 이입 몰입 엄마 아빠 회사 시사회 국민 배우 송강호 찬사 류준열 그동안 영화 독일 기자 서울 택시 운전사 시선 영화 언론통제 날 참상 인간 분노 역사 그때 죄 마음 영화 상처 역사 영화 택시 운전사 전두환 역사 민족 미래 영화 택시 운전사 오전 개봉 다큐 고증 오락 픽션 구성 최근 광주 관련 영상 압권 생각 추천 영화 영화 가슴 김 사복 애국 열사 전두환 영화 시사회 때 돈 돈 값 영화 민주 운동 나라 교과서 줄 민주 희생 전 금남 거리 송강호 연기 최고 감동 묘사 이유 베 평점 테러 시작 광주 사람 마음 거부 광주 그날 감동 경험 감사 영화 보고 광주 민주 운동 홍어 빨갱이 폭도 무식 사람 오랜만 한국 영화 배우 연기 감동 송강호 감정 연기 가슴 최고 송강호 최고 이유 유해진 대박 류준열 반전 대박 군함 실망 맘 정화 눈물 영화 울림 배우 연기 여운  송강호 유해진 류준열 외국 배우 연기 송강호 시선 외부 입장 공감대 형성 감정 택시 운전사 평점 테러 베 충 사회악 인생 영화 진심 송강호 진심 갑 정권 일 본인 이익 영화 소신 참여 변호인 때 최고 배우 시민 군인 고인 명복 빕 택시 운전사 시사회 슬픔 분노 눈물 지금 세상 감사 명연기 명배우 감탄사 대신 오랫만 시사회 추천 영화 주연 배우 연기 류준열 앞 기대 배우 모자람 완벽 조합 최고 캐스팅 굿 굿 인종 성격 분노 사람 영화 토마스 크레취만 피아니스트 영화 휴머니스트 모습 시민 역사 진실 앞 눈 애기 필요 영화 감동 영화 광주 탈출 때 택시 추격 아쉬움 지금 민주주의 감사 기대 현실 속 감동 억지 신파 택시 운전사 시선 그날 현장 담당 울림 보람 인간 색마 사이코패스 권력 광주 시민 희생 부끄러움 순간 인간 숨 기억 영화관 처음 영화 감사 실화 맘 민주 운동 희생자 애 감사 코엑스 시사회 관람 사건 진행 이방인 외국 기자 서울 택시 기사 감정 변화 부족 신파 국 뽕 감동 송강호 베 충이 베 군함 생각 영화 송강호 짱 울엄마 영화 광주 사람 영화 우연 외부 택시 운전사 초점 기자 학생 시민 사명 당위 설명 관객 설득 자연 택시 운전사 사람 외면 상황 대부분 외부 일 가슴 진실 세상 감사 영화 제작자 배우 감사 죄 총칼 앞 고인 넋 위로 실화 바탕 영화 당시 광주 학생 시민 죽음 마음 눈물 속 선택 마음 영화 중간 시간 감동 눈시울 영화 날 기억 강추 그날 이야기 기억 업적 이야기 좌파 영화 미친놈 국민 떼거지 실화 옹호 역사 시사 송강호 때 눈물 용기 내서 감사 개봉 날 보람 영화 장훈 감독 배우 조합 최고 이번 주말 차 택시 운전사 운 시사회 개봉 날 예매 이웃 아픔 표현 배우 연기 구재 식역 류준열 인상 영화 개봉 엄마 조조 관람 영화 관내 숨소리 영화 이번 이유 바위 침묵 엄마 진실 사람 역사책 장면 감상 기분 생애 처음 개봉 날 조조 영화 택시 운전사 군부 독재 잔혹 인간 길 포기 군부 독재 세력 심판 억지 감동 포기 끝 감사 교복 학생 병원 피 장면 눈물 나라 희생 광주 시민 위험 상황 진실 노력 위르겐 힌츠페터 김 사복 감사 지금 광주 교육 필요 생각 영화 감사 민주 유공자 아들 후회 역사 기록 날 일 눈 기자 감사 말 택시 드라이버 굿 굿 굿 굿 황정민 송강호 영화 가슴 영화 배우 연기 영화 송강호 유해진 영화 재미 감동 남치 영화 초등학생 딸 자녀 영화 보시기 적극 추천 광주 민주 항쟁 생각 배우 송강호 자신 출연 영화 안목 생각 영화 광주 사람 지역 사람 외국인 눈 피 광주 현장 정도 순화 관람 동안 감동 재미 영화 위르겐 힌츠페터 기자 감사 가슴 오랜만 영화 시사회 부모 눈물 감동 자체 소문 사실 민주 운동 영화 역사 이름 희생 영웅 기억 완전 대박 생각 역사 역사 민족 미래 그날 이야기 기억 업적 이야기 입장 류준열 모습 신파 여름 영화 전두 처벌 나라 생각 광주 시민 존경 표 감동 시절 덕택 행복 감사 송강호 영화 기대 영화 가족 민주주의 나무 피 피 자유 정의 대한민국 민주주의 나무 재미 감동 역사 사실 화 마음 희생 정신 오늘날 실화 시점 광주 슬픔 여운 택시 기사 다음 날 지시 시민 지금 대한민국 현실 감동 아들 최고 영화 아들 감동 송강호 역쉬 엄지 세계 송강호 연기 민국 오늘 류준열 오전 상영 기대 영화 관람 후 만족 가슴 동안 기억 영화 대한민국 국민 영화 강추 영화 연기 연출 취 광주 money 역사 가슴 역사 역사 반성 발전 나라 근래 마음 영화 오랜만 장면 감동 말 필요 배우 송강호 멋 실화 가슴 영화 연기 밋 추천 광주 민주 운동 계기 시사회 손수건 생각 역사 역사 말 시사회 호평 입소문 기대 베 충 평점 테러 평점 테러 참 짓 평점 테러 영화 반응 입소문 올해 국내 영화 탑 광주 생각 분통 광주 사람 일 역쉬 송강호 죠 배 우분 연기 내용 영화 중간 중간 요소 영화 현대사 부분 점 감동 타임머신 광주 기분 여운 티켓 값 이상 가치 영화 민주 운동 세상 희생 영화관 개봉 영화 기대 감동 재미 가슴 메세지 송강호 유해진 류준열 느낌 합 개봉 시간 영화 휴가 시사회 감동 역사 저서 눈물 영화 시사회 돈 영화 가족 친구 류준열 재식 생각 시사회 가족 친구 영화 실화 감동 개봉 전 시사회 초대 영화 감동 여운 개봉 대갈 뚝배기 영화 시민 영웅 시민 진실 과정 표현 이상 여운 영화 자유 평화 광주 생존자 표현 실제 광주 사람 그때 이후 자식 허리 칼 엄마 통제 폭 취급 지금 욕 광주 임팩트 여운 감동 송강호 배우 무게 영화 재미 슬픔 영화 감사 억지 군함 정도 영화 바램 나라 역사 가슴 아픔 배우 연기 마음 류준열 얼굴 마음 실화 바탕 볼 영화 처음 끝 장면 영화 감동 트 노력 기자 기사 박수 부모 시사회 극장 아버지 처음 눈물 손수건 시절 아픔 부모 공감 영화 가슴 일 멋 가슴 전 대학생 때 추억 날 추억 영화 명불허전 송강호 류준열 유해진 배우 연기 감동 영화 김 마음 민주주의 시간 눈물 광주 모습  그날 지금 대한민국 희생 영화 베가 주제 영화 진실 생각 인생 영화 그때 아픔 베 충 틈 영화 역사 사실 마음 말 필요 최고 영화 소소 밋 밧 동안 광주 군함 최고 일 나라 지구촌 곳 역사 반복 사실 영상 무척 감명 눈물 애 가족 시간 시간 오랜만 가슴 시간 강추 역사 가슴 역사 영화 전두 역쉬 송강호 생각 류준열 연기 실망 유해진 역시 광주 민주 운동 말 장훈 브랜드 감동 군함 평론가 평점 군함 베 영화 사람 댓글 폭동 군사 정권 전 대갈 하수 역사 영화 돈 군함 도랑 차원 시사회 송강호 유해진 류준열 토마스 배우 송강호 아빠 손 대사 최고 명장면 실화 바탕 말 필요  송강호 기력 연기자 감동 연기 오랜만 감동 베 벌레 배우 연기 짱 영화 가슴 영화 실화 바탕 제작 가슴 역사 영화 송강호 영화 광주 민주 항쟁 가슴 한참 시사회 시대 사람 마음 영화 감동 관심 자신 반성 배우 연기 조합 감독 연출 시사회 평점 울림 의미 영화 영화 속 의미 크기 배우 연기 두말 영화 반복 전 묘지 유쾌 감동 아들 시간 송강호 배우 연기 내용 감동 재미 재미 한국인 영화 생각 역사 최고 그때 시절 생각 가슴 아이 영화 눈물 대한민국 군부 독재 시대 상황 당시 국민 애환 영화 실화 바탕 작품 가슴 개인 완성도 영화 세대 다음 세대 추천 영화 전 죄 값 사람 탈 짐승 그날 일 뒤 손가락 인간 강추 강추 눈물 평점 사람 광주 비극 역사 폭동 일 베 웃음 눈물 유머 어간 영화 감동 눈물 영화 영화 아침 기대 돈 강추 사람 지루 틈 장면 시간 시간 송강호 연기 여운 영화 길 가슴 울림 영화 베 영화 관심 평점 테러 일본 상관 군함 개봉 당일 새벽 기습 평점 테 ...

# %%
# TF-IDF 계산
tfidf.calculation_tfidf(movie_comment_list, 
                        tf_vectorizer_path="data/tf_vectorizer", 
                        tfidf_vectorizer_path="data/tfidf_vectorizer")
tfidf_matrix = tfidf.get_tfidf_matrix().values[:]

# 정답 label 불러오기
label_list = movie_viewer_list

# 학습데이터/평가데이터 분리
x_train, x_test, y_train, y_test = train_test_split(tfidf_matrix, label_list, test_size=0.20, random_state=True)

# %% [markdown]
# ### 2. 학습하기
#
# ---

# %%
mlr_model = LinearRegression()
mlr_model.fit(x_train, y_train) 

# 학습모델 저장
fh.save_data("data/mlr_model", mlr_model)

# %%
y_predict = mlr_model.predict(x_train)

# %%
plt.scatter(y_train, y_predict, alpha=0.4)
plt.xlabel("Actual Viewer")
plt.ylabel("Predicted Viewer")
plt.title("MULTIPLE LINEAR REGRESSION")
plt.show()

# %%
y_predict = mlr_model.predict(x_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test, y_predict, alpha=0.4)
plt.xlabel("Actual Viewer")
plt.ylabel("Predicted Viewer")
plt.title("MULTIPLE LINEAR REGRESSION")
plt.show()

# %% [markdown]
# ### 3. R-Squared 평가하기
#
# ---

# %%
r_squared = mlr.score(x_train, y_train)
print("전체 영화 관객수 데이터의", r_squared, "를 설명 가능한 모델로 평가됨")
# Out:
# 전체 영화 관객수 데이터의 0.9320994099527853 를 설명 가능한 모델로 평가됨

# %% [markdown]
# ### 4. 학습모델 활용하기
#
# ---

# %% [markdown]
# #### 4.1. 새로운 영화리뷰 수집하기
#
# ---

# %%
from bs4 import BeautifulSoup 
import requests
import datetime

# %%
#MOVIE_CODE = "76016"
#MOVIE_CODE = "73318"
MOVIE_CODE = "130786"
#TITLE = "써니"
#TITLE = "시라노 연애조작단"
TITLE = "조선마술사"

SAVE_FILE_PATH = "data/movie_comment.txt"
f = open(SAVE_FILE_PATH, "w", encoding="utf-8")


# 전체 댓글개수 가져오기
URL = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=" + MOVIE_CODE + "&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1"
response = requests.get(URL)
soup = BeautifulSoup(response.text, "html.parser")
comment_total = int(soup.find("strong", {'class': "total",}).find("em",).text.replace(",", ""))
page_limit = comment_total/10
if page_limit % 1 > 0:
    page_limit = int(page_limit) + 1
else:
    page_limit = int(page_limit)
# 댓글 가져오기
for page in range(1, page_limit+1):
    print(page, "/", page_limit, end="\r")
    URL = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=" + MOVIE_CODE + "&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page="
    URL = URL + str(page)
    response = requests.get(URL)
    soup = BeautifulSoup(response.text, "html.parser")
    comment_list = soup.findAll("div", {'class': "score_reple",})
    for comment in comment_list:
        try:
            span_tag_list = comment.find("p").findAll("span")
            date_time = comment.findAll("em")[1].text
            if span_tag_list[0].text == "관람객":
                f.write(TITLE + "\t" + date_time + "\t" + span_tag_list[1].text.strip() + "\n")
            else:
                f.write(TITLE + "\t" + date_time + "\t" + span_tag_list[0].text.strip() + "\n")
        except:
            continue
    f.flush()
    
f.close()
# Out:
# 487 / 487

# %% [markdown]
# #### 4.2. 개봉일 이후 3개월 리뷰만 필터링하기
#
# ---

# %%
#opening_date = "20110504" # 써니
#opening_date = "20100916" # 시라노 연애조작단
opening_date = "20151230" # 조선마술사

sample_data = []
progress = 0

f = open("data/movie_comment.txt", encoding="utf-8")
for line in f:
    progress += 1
    print(progress, end="\r")
    
    line = line.replace("\n", "")
    #print(line)
    col = line.split("\t")
    try:
        movie_name = col[0]
        date_time = col[1]
        _date_time = datetime.datetime.strptime(date_time, "%Y.%m.%d %H:%M")
        opening_datetime = datetime.datetime.strptime(opening_date, "%Y%m%d")
        comment = col[2]
        # 개봉일 이전 리뷰만 필터링
        #print(_date_time, opening_date)
        if _date_time <= opening_datetime + datetime.timedelta(days=3):
            sample_data.append([movie_name, date_time, comment])
    except:
        continue
f.close()
# Out:
# 4868

# %%
len(sample_data)
# Out:
# 1994

# %%
sample_data[:3]
# Out:
# [['조선마술사',
#   '2015.12.30 23:01',
#   '끼워맞춘듯한 캐릭터설정, 장르는 드라마인데 드라마도 아니고 코믹도 아니고 액션도 아니고 멜로도 아니고 어정쩡한 기분, 큰 스크린에서 볼때 엄청 어색했던 CG, 인과성이 부족한 장면전환, 총체적 난국인데 글을 잘 못써...'],
#  ['조선마술사',
#   '2015.12.30 20:37',
#   '주인공은 마술하랬더니 연애하고 있고, 제작사는 사극기대하게 해놓고는 웹소설 만들어놓고, 배급사는 마케팅은 안하고 알바들만 풀어놓는구나...'],
#  ['조선마술사', '2015.12.30 20:34', '유승호의 눈이 파란건 도데체 무엇을 의도한걸까 ㅋㅋㅋ']]

# %%
pos_sentence = ""

for movie_name, date_time, comment in sample_data:
    pos_result = ma.parse(comment)
    pos_sentence += " " + processing.get_plain_text(pos_result, pos_list=POS_LIST, tag=False)

# %%
pos_sentence[:200]
# Out:
# ' 캐릭터 설정 장르 드라마 드라마 코믹 액션 멜 기분 스크린 때 인과 부족 장면 전환 총체 난국 글 주인공 마술 연애 제작사 사극 기대 웹 소설 배급사 마케팅 유승호 눈 의도 도대 장르 글 도중 토 중간 좌석 욕 영화 대나 사실 영화 볼 영화 곽도원 대신 주인공 영화 끝 내생 영화 처음 조선 알 돈 결말 전체 내용 돈 시간 글 최근 영화 최악 내용 편집 재'

# %%
input_vector = tfidf.get_tfidf_vector(pos_sentence, tfidf_vectorizer_path="data/tfidf_vectorizer")
# 학습모델 불러오기
model = fh.load_data("data/mlr_model")
# 분류수행
predict = int(model.predict([input_vector]).tolist()[0])
predict
# Out:
# 567830

# %% [markdown]
#     - 영화관객수 확인 링크
# > http://www.kobis.or.kr/kobis/business/main/main.do
